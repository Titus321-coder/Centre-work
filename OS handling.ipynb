# %%
#   ' '.join(to join or make a single string

# %%
import os

# %%
os.mkdir('data')

# %%
os.listdir('data1.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.listdir('data1.txt')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data1.txt'

# %%
os.getcwd()
# Out:
# 'D:\\python'

# %%
os.chdir('D:\\python\\dir')

# %%
with open('s_data.txt', mode =='r'):
# Out:
#   Cell In[19], line 1
#     with open('s_data.txt', mode =='r'):
#                                         ^
# _IncompleteInputError: incomplete input

# %%
os.walk('dir')

# %%
for path, listdir, listfile in os.walk('s_data.txt'):
    print("Path:" ,path) 
    print(f"Total dir: {len(listdir)} : {','.join(listdir)}")
    print(f"Total file: {len(listdir)} : {','.join(listfile)}")
    print("*"*10)
