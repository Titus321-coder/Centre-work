# %%
# outlier which is a complete data from your actual data as in 100 is actual but the value is 110
# Mean , Median , Mode & Standard Deviation

# %%
# median is used to find the outlier value
# mean is used when there is no outlire and is in linear form
# when you need repeatation of value or customer
# if you wish to find the outlire mean and median will not be the same or it will we be -
# outlier is found in your data and is different from your data set
# pd.to_datetime(varible_file.order_date)[0].strftime('
#orders.order_data.dt.year

# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('vyrqmE.csv')

# %%
df
# Out:
#      order_id customer_id product_id  quantity  order_date
# 0      O00001       C0333       P022         1  2022-01-09
# 1      O00002       C0068       P090         1  2022-01-27
# 2      O00003       C0483       P021         1  2022-01-17
# 3      O00004       C0214       P076         4  2022-01-07
# 4      O00005       C0411       P073         4  2022-01-12
# ...       ...         ...        ...       ...         ...
# 2579   O02580       C0237       P098         5  2024-12-22
# 2580   O02581       C0236       P007         1  2024-12-05
# 2581   O02582       C0029       P035         1  2024-12-12
# 2582   O02583       C0171       P077         1  2024-12-16
# 2583   O02584       C0421       P038         5  2024-12-01
#
# [2584 rows x 5 columns]

# %%
df['order_date'] = pd.to_datetime(df.order_date)

# %%
df
# Out:
#      order_id customer_id product_id  quantity order_date
# 0      O00001       C0333       P022         1 2022-01-09
# 1      O00002       C0068       P090         1 2022-01-27
# 2      O00003       C0483       P021         1 2022-01-17
# 3      O00004       C0214       P076         4 2022-01-07
# 4      O00005       C0411       P073         4 2022-01-12
# ...       ...         ...        ...       ...        ...
# 2579   O02580       C0237       P098         5 2024-12-22
# 2580   O02581       C0236       P007         1 2024-12-05
# 2581   O02582       C0029       P035         1 2024-12-12
# 2582   O02583       C0171       P077         1 2024-12-16
# 2583   O02584       C0421       P038         5 2024-12-01
#
# [2584 rows x 5 columns]

# %%
df['Year'] = df.order_date.dt.year

# %%
df['Month'] = df.order_date.dt.month

# %%
df
# Out:
#      order_id customer_id product_id  quantity order_date  Year  Month
# 0      O00001       C0333       P022         1 2022-01-09  2022      1
# 1      O00002       C0068       P090         1 2022-01-27  2022      1
# 2      O00003       C0483       P021         1 2022-01-17  2022      1
# 3      O00004       C0214       P076         4 2022-01-07  2022      1
# 4      O00005       C0411       P073         4 2022-01-12  2022      1
# ...       ...         ...        ...       ...        ...   ...    ...
# 2579   O02580       C0237       P098         5 2024-12-22  2024     12
# 2580   O02581       C0236       P007         1 2024-12-05  2024     12
# 2581   O02582       C0029       P035         1 2024-12-12  2024     12
# 2582   O02583       C0171       P077         1 2024-12-16  2024     12
# 2583   O02584       C0421       P038         5 2024-12-01  2024     12
#
# [2584 rows x 7 columns]

# %%
df['quantity'].sum()
# Out:
# np.int64(7797)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2584 entries, 0 to 2583
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     2584 non-null   object
#  1   customer_id  2584 non-null   object
#  2   product_id   2584 non-null   object
#  3   quantity     2584 non-null   int64
#  4   order_date   2584 non-null   datetime64[ns]
#  5   Year         2584 non-null   int32
#  6   Month        2584 non-null   int32
# dtypes: datetime64[ns](1), int32(2), int64(1), object(3)
# memory usage: 121.3+ KB

# %%
df['Year'].mode()
# Out:
# 0    2023
# Name: Year, dtype: int32

# %%
order_group = df.groupby('Year')

# %%
order_group.get_group(2023)['customer_id'].mode()
# Out:
# 0    C0414
# Name: customer_id, dtype: object

# %%
order_group.get_group(2024)['customer_id'].mode()
# Out:
# 0    C0220
# Name: customer_id, dtype: object

# %%
order_group.get_group(2022)['customer_id'].mode()
# Out:
# 0    C0028
# 1    C0080
# 2    C0129
# 3    C0267
# Name: customer_id, dtype: object

# %%
order_group.get_group(2023).quantity.sum()
# Out:
# np.int64(2861)

# %%
order_group.get_group(2024).quantity.sum()
# Out:
# np.int64(2387)

# %%
order_group.get_group(2022).quantity.sum()
# Out:
# np.int64(2549)

# %%
order_group.get_group(2022)['product_id'].value_counts().idxmax()
# Out:
# 'P059'

# %%
order_group.get_group(2022)['product_id'].value_counts().idxmax()
# Out:
# 'P059'

# %% [markdown]
# # DF concate

# %%
#pd.concat
#table.merge(primary table, on = primary key name)
#

# %%
customer = pd.read_csv("vyrqmE.csv")

# %%
product = pd.read_csv("products.csv")

# %%
product
# Out:
#    product_id product_name     category   price
# 0        P001        Stage     Clothing  534.93
# 1        P002        Least  Accessories   56.56
# 2        P003       Number         Home  339.92
# 3        P004      Evening     Clothing  138.74
# 4        P005      Protect     Footwear   68.06
# ..        ...          ...          ...     ...
# 95       P096      Service     Footwear  872.76
# 96       P097         Away         Home  932.46
# 97       P098     Decision  Accessories  567.31
# 98       P099           So  Electronics  698.17
# 99       P100   Everything         Home  922.89
#
# [100 rows x 4 columns]

# %%
complete = customer.merge(product , on = "product_id")

# %%
complete
# Out:
#      order_id customer_id product_id  quantity  order_date product_name  \
# 0      O00001       C0333       P022         1  2022-01-09          Tax
# 1      O00002       C0068       P090         1  2022-01-27      Perform
# 2      O00003       C0483       P021         1  2022-01-17          Art
# 3      O00004       C0214       P076         4  2022-01-07       Amount
# 4      O00005       C0411       P073         4  2022-01-12       Second
# ...       ...         ...        ...       ...         ...          ...
# 2579   O02580       C0237       P098         5  2024-12-22     Decision
# 2580   O02581       C0236       P007         1  2024-12-05       Finish
# 2581   O02582       C0029       P035         1  2024-12-12        First
# 2582   O02583       C0171       P077         1  2024-12-16   Government
# 2583   O02584       C0421       P038         5  2024-12-01        Black
#
#          category   price
# 0            Home  185.33
# 1     Electronics  947.55
# ...

# %%
complete["Total_Price"] = (complete.quantity * complete.price)

# %%
complete
# Out:
#      order_id customer_id product_id  quantity  order_date product_name  \
# 0      O00001       C0333       P022         1  2022-01-09          Tax
# 1      O00002       C0068       P090         1  2022-01-27      Perform
# 2      O00003       C0483       P021         1  2022-01-17          Art
# 3      O00004       C0214       P076         4  2022-01-07       Amount
# 4      O00005       C0411       P073         4  2022-01-12       Second
# ...       ...         ...        ...       ...         ...          ...
# 2579   O02580       C0237       P098         5  2024-12-22     Decision
# 2580   O02581       C0236       P007         1  2024-12-05       Finish
# 2581   O02582       C0029       P035         1  2024-12-12        First
# 2582   O02583       C0171       P077         1  2024-12-16   Government
# 2583   O02584       C0421       P038         5  2024-12-01        Black
#
#          category   price  Total_Price
# 0            Home  185.33       185.33
# ...

# %%
complete['order_date'] = pd.to_datetime(complete.order_date)

# %%
complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2584 entries, 0 to 2583
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      2584 non-null   object
#  1   customer_id   2584 non-null   object
#  2   product_id    2584 non-null   object
#  3   quantity      2584 non-null   int64
#  4   order_date    2584 non-null   datetime64[ns]
#  5   product_name  2584 non-null   object
#  6   category      2584 non-null   object
#  7   price         2584 non-null   float64
#  8   Total_Price   2584 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 181.8+ KB

# %%
complete['Year'] = complete.order_date.dt.year
complete['Month'] = complete.order_date.dt.month

# %%
complete[complete.Year == 2023]
# Out:
#      order_id customer_id product_id  quantity order_date product_name  \
# 828    O00829       C0373       P033         4 2023-01-22          The
# 829    O00830       C0010       P064         2 2023-01-25       Likely
# 830    O00831       C0335       P082         1 2023-01-29         West
# 831    O00832       C0478       P005         4 2023-01-21      Protect
# 832    O00833       C0137       P020         3 2023-01-19        Light
# ...       ...         ...        ...       ...        ...          ...
# 1747   O01748       C0168       P086         4 2023-12-10         Edge
# 1748   O01749       C0249       P060         1 2023-12-27   Management
# 1749   O01750       C0043       P071         2 2023-12-12         Same
# 1750   O01751       C0366       P057         2 2023-12-26           On
# 1751   O01752       C0242       P036         2 2023-12-13         News
#
#          category   price  Total_Price  Year  Month
# 828      Footwear  666.87      2667.48  2023      1
# ...

# %%
Yearly_2022 = complete.groupby('Year')
Monthly_2022 = Yearly_2022.get_group(2022).groupby('Month')
Yearly_2023 = complete.groupby('Year')
Monthly_2023 = Yearly_2023.get_group(2023).groupby('Month')
Yearly_2024 = complete.groupby('Year')
Monthly_2024 = Yearly_2024.get_group(2024).groupby('Month')

# %%
Monthly_2022['product_name'].value_counts().idxmax()
# Out:
# (np.int32(1), 'Table')

# %%
Yearly_2023['product_name'].value_counts().idxmax()
# Out:
# (np.int32(2023), 'North')

# %%
for i in Monthly_2022:
    print(F"Max selling product is:{i}")
# Out:
# Max selling product is:(1,    order_id customer_id product_id  quantity order_date product_name  \
# 0    O00001       C0333       P022         1 2022-01-09          Tax
# 1    O00002       C0068       P090         1 2022-01-27      Perform
# 2    O00003       C0483       P021         1 2022-01-17          Art
# 3    O00004       C0214       P076         4 2022-01-07       Amount
# 4    O00005       C0411       P073         4 2022-01-12       Second
# ..      ...         ...        ...       ...        ...          ...
# 94   O00095       C0053       P079         5 2022-01-23        Dream
# 95   O00096       C0443       P029         5 2022-01-28      Believe
# 96   O00097       C0200       P031         5 2022-01-16          Eat
# 97   O00098       C0402       P090         3 2022-01-26      Perform
# 98   O00099       C0355       P086         1 2022-01-14         Edge
#
#        category   price  Total_Price  Year  Month
# 0          Home  185.33       185.33  2022      1
# ...

# %%
def selling():
    for i in Monthly_2023:
        print(F"Max selling product is:{complete.product_id.idxmax()}")

# %%
selling()
# Out:
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268
# Max selling product is:268

# %%
for i in Monthly_2024.idxmax():
    print(F"Max selling product is:{Yearly_2024.idxmax()}")
# Out:
# Max selling product is:      order_id  customer_id  product_id  quantity  order_date  product_name  \
# Year
# 2022       827          267         268         6         792            48
# 2023      1751          993         887       833        1712           873
# 2024      2583         2113        1926      1760        2558          1771
#
#       category  price  Total_Price  Month
# Year
# 2022         0    113          236    767
# 2023       829    846         1316   1667
# 2024      1753   1768         2102   2519
# Max selling product is:      order_id  customer_id  product_id  quantity  order_date  product_name  \
# Year
# 2022       827          267         268         6         792            48
# 2023      1751          993         887       833        1712           873
# 2024      2583         2113        1926      1760        2558          1771
#
#       category  price  Total_Price  Month
# Year
# 2022         0    113          236    767
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 Monthly_2024.get_group("product_name")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\groupby\groupby.py:1116, in BaseGroupBy.get_group(self, name, obj)
#    1114 inds = self._get_index(name)
#    1115 if not len(inds):
# -> 1116     raise KeyError(name)
#    1118 if obj is None:
#    1119     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 'product_name'

# %%
order_group1.get_group(2022)['product_name'].value_counts().idxmax()
# Out:
# 'Network'

# %%
order_group2.get_group(1)['product_name'].value_counts().idxmax()
# Out:
# 'Table'

# %%
order_group1.get_group(2022)['product_name'].value_counts().idxmin()
# Out:
# 'Follow'

# %%
order_group2.get_group(1)['product_name'].value_counts().idxmin()
# Out:
# 'Art'

# %%
order_group1.get_group(2022)['product_id'].value_counts().idxmax()
# Out:
# 'P059'

# %%
order_group1.get_group(2022)['product_id'].value_counts().idxmin()
# Out:
# 'P054'

# %%
order_group1.get_group(2022).Total_Price.sum()
# Out:
# np.float64(1357500.38)

# %%
order_group1.get_group(2023).Total_Price.sum()
# Out:
# np.float64(1489071.01)

# %%
order_group1.get_group(2024).Total_Price.sum()
# Out:
# np.float64(1287689.2000000002)

# %%
complete.to_csv("Complete_order.csv")
